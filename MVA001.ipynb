# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiraporn-klobrat/multivariate-/blob/main/MVA001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scalar,Vector,Matrix

# %% [markdown]
# # Scalar

# %%
 import numpy as np

# %%
scalar_a = 10    #scalar
print(scalar_a)
# Out:
# 10

# %% [markdown]
# # Vector

# %% [markdown]
# ![145409851_449373232867491_7020223303477016064_n.jpg](data:image/jpeg;base64,...)

# %%
vector_b = np.zeros([2,1])    #vector
vector_b[0,0] = 1
vector_b[1,0] = 3
print(vector_b)
print(vector_b.shape)
# Out:
# [[1.]
#  [3.]]
# (2, 1)

# %%
vector_c = np.array([[1],[3]])
print(vector_c)
print(vector_c.shape)
# Out:
# [[1]
#  [3]]
# (2, 1)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(vector_b[0,0],vector_b[1,0],'or')

# %% [markdown]
# ขนาดของ vector คำนวณได้โดย พิทากอรัส

# %%
vector_b_size = ((vector_b[0,0]**2) + (vector_b[1,0]**2))**0.5
print(vector_b_size)
# Out:
# 3.1622776601683795

# %% [markdown]
# # Matrix

# %% [markdown]
# ![145409851_449373232867491_7020223303477016064_n.jpg](data:image/jpeg;base64,...)

# %%
matrix_d = np.array([[2,3],[1,4],[-1,1]])
print(matrix_d)
# Out:
# [[ 2  3]
#  [ 1  4]
#  [-1  1]]

# %%
matrix_d = matrix_d.T
print(matrix_d)
# Out:
# [[ 2  1 -1]
#  [ 3  4  1]]

# %%
matrix_d[0,:]
# Out:
# array([ 2,  1, -1])

# %%
plt.plot(matrix_d[0,:],matrix_d[1,:], 'or')    ## plot(ค่าx, ค่าy, หน้าตาของจุด)
plt.plot(0,0, '.b')     ## plot(ค่าx, ค่าy, หน้าตาของจุด)
plt.plot([0,0],[-1,5], ':k')
plt.plot([-1.5,2.5],[0,0], ':k')

# %% [markdown]
# ##Transpose

# %%
A = np.array([[3,-1,2],[1,5,4]])
print(A)
# Out:
# [[ 3 -1  2]
#  [ 1  5  4]]

# %%
A.T
# Out:
# array([[ 3,  1],
#        [-1,  5],
#        [ 2,  4]])

# %% [markdown]
# ##Matrix Multiply

# %% [markdown]
# $B = A*A'$

# %%
B = np.dot(A,A.T)
print(B)
# Out:
# [[14  6]
#  [ 6 42]]

# %% [markdown]
# ## Determinant

# %% [markdown]
# $Det(B)$

# %%
np.linalg.det(B)
# Out:
# 551.9999999999998

# %% [markdown]
# linalg = linear algebra

# %% [markdown]
# maltrix algebra เพิ่มเติม

# %%
plt.plot([0,1],[0,1], '-r' )    ## vector [1,1]
plt.plot(0,0, '.b' )
plt.plot([0,0],[-1,5], '^:k' )
plt.plot([-1.5,2.5],[0,0], '>:k' )

# %%
B = np.array([[1,2],[3,4]])
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# การคูณ Matrix (B.v) คือ การทำ linear transformation

# %%
v = np.array([[1],[1]])
v
# Out:
# array([[1],
#        [1]])

# %%
Bv = np.dot(B,v)
Bv
# Out:
# array([[3],
#        [7]])

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]], '-g' )    ## vector Bv
plt.plot([0,1],[0,1], '-r' )    ## vector [1,1]
plt.plot(0,0, '.b' )
plt.plot([0,0],[-1,5], '^:k' )
plt.plot([-1.5,2.5],[0,0], '>:k')

# %% [markdown]
# Determinant ของ Matrix ($Det(B)$) คือ พื้นที่ของ unit vector ที่ถูกเปลี่ยนไป โดย Matrix นั้นๆ

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]], '-g' )    ## vector Bv
plt.plot([3,3],[7,0], ':g' )    ## วาดจุดไข่ปลา พื้นที่ของ
plt.plot([3,0],[7,7], ':g' )    ## วาดจุดไข่ปลา พื้นที่ของ
plt.plot([0,1],[0,1], '-r' )    ## vector v ([1,1])
plt.plot([1,1],[1,0], ':r' )    ## วาดจุดไข่ปลา พื้นที่ของ
plt.plot([1,0],[1,1], ':r' )    ## วาดจุดไข่ปลา พื้นที่ของ
plt.plot(0,0, '.b' )
plt.plot([0,0],[-1,8], '^:k' )
plt.plot([-1.5,3.5],[0,0], '>:k')

# %% [markdown]
# Identity matrix ($I$)
#
# $BI = B = IB$

# %%
iden2 = np.identity(2)

# %%
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.dot(B,iden2)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
np.dot(iden2,B)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
C = np.array([[-1,2],[2,4]])
C
# Out:
# array([[-1,  2],
#        [ 2,  4]])

# %%
np.dot(B,C)
# Out:
# array([[ 3, 10],
#        [ 5, 22]])

# %%
np.dot(C,B)
# Out:
# array([[ 5,  6],
#        [14, 20]])

# %% [markdown]
# การบ้านในห้อง

# %%
import numpy as np
D = np.array([[3,1,6],[7,4,5],[2,-7,1]])
print(D)
# Out:
# [[ 3  1  6]
#  [ 7  4  5]
#  [ 2 -7  1]]

# %%
np.linalg.det(D)
# Out:
# -221.99999999999997

# %% [markdown]
# Eigen value กับ Eigen vector
#
# - Eigen value($\lambda$) -> $|A-\lambda I| =0$
# - Eigen vector(x) -> $Ax = $\lambda$x$

# %% [markdown]
# HW5 หา Eigen value กับ Eigen vector ของ
#
# ![145153953_408458787116478_5992038338145095510_n.jpg](data:image/jpeg;base64,...)
