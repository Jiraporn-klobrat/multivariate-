# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiraporn-klobrat/multivariate-/blob/main/Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การนำเข้าข้อมูล pizza

# %%
import pandas as pd

# %%
data = pd.read_csv('Pizza.csv')#กำหนดชื่อตัวแปร
data                                       #แสดงข้อมูล
# Out:
#     brand     id   mois   prot    fat   ash  sodium   carb   cal
# 0       A  14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1       A  14053  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2       A  14025  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3       A  14016  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4       A  14005  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..    ...    ...    ...    ...    ...   ...     ...    ...   ...
# 295     J  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296     J  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297     J  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298     J  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299     J  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 9 columns]

# %%
data = pd.read_csv('Pizza.csv')   #กำหนดชื่อตัวแปร
data.head(10) #แสดงตัวอย่าง 10 ตัว
# Out:
#   brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1     A  14053  28.49  21.26  43.89  5.34    1.79  1.02  4.84
# 2     A  14025  28.35  19.99  45.78  5.08    1.63  0.80  4.95
# 3     A  14016  30.55  20.15  43.13  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28  41.65  4.82    1.64  1.76  4.67
# 5     A  14075  31.14  20.23  42.31  4.92    1.65  1.40  4.67
# 6     A  14082  31.21  20.97  41.34  4.71    1.58  1.77  4.63
# 7     A  14097  28.76  21.41  41.60  5.28    1.75  2.95  4.72
# 8     A  14117  28.22  20.48  45.10  5.02    1.71  1.18  4.93
# 9     A  14133  27.72  21.19  45.29  5.16    1.66  0.64  4.95

# %% [markdown]
# # ตรวจสอบขนาดของข้อมูล

# %%
data.shape    #ตรวจสอบว่าข้อมูลมีกี่ตัว
# Out:
# (300, 9)

# %% [markdown]
# # ดูการกระจายของข้อมูล โดยการ plot scatter matrix

# %%
pd.plotting.scatter_matrix(data);

# %% [markdown]
# #เลือกมาทำเฉพาะข้อมูลที่เป็นตัวเลข

# %%
data.iloc[:,1:]    #เนื่องจากข้อมูลใน column1 เป็นข้อมูลข้อมูลที่ไม่ใช่ตัวเลข จึงตัด column1 ออก
# Out:
#         id   mois   prot    fat   ash  sodium   carb   cal
# 0    14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1    14053  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2    14025  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3    14016  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4    14005  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..     ...    ...    ...    ...   ...     ...    ...   ...
# 295  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 8 columns]

# %%
newdata = data.iloc[:,1:]
newdata.head()
# Out:
#       id   mois   prot    fat   ash  sodium  carb   cal
# 0  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1  14053  28.49  21.26  43.89  5.34    1.79  1.02  4.84
# 2  14025  28.35  19.99  45.78  5.08    1.63  0.80  4.95
# 3  14016  30.55  20.15  43.13  4.79    1.61  1.38  4.74
# 4  14005  30.49  21.28  41.65  4.82    1.64  1.76  4.67

# %% [markdown]
# # ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
np.corrcoef(newdata)
# Out:
# array([[1.        , 1.        , 0.99999999, ..., 0.99999599, 0.9999943 ,
#         0.99999426],
#        [1.        , 1.        , 0.99999998, ..., 0.99999618, 0.99999457,
#         0.99999454],
#        [0.99999999, 0.99999998, 1.        , ..., 0.99999586, 0.99999427,
#         0.99999424],
#        ...,
#        [0.99999599, 0.99999618, 0.99999586, ..., 1.        , 0.99999817,
#         0.99999822],
#        [0.9999943 , 0.99999457, 0.99999427, ..., 0.99999817, 1.        ,
#         0.99999999],
#        [0.99999426, 0.99999454, 0.99999424, ..., 0.99999822, 0.99999999,
#         1.        ]])

# %%
corr = np.corrcoef(newdata.to_numpy().T)    #.T เพื่อทำการสลับแถวสลับหลัก

# %%
corr.shape      # .shape เพื่อดูขนาดของ corr
# Out:
# (8, 8)

# %%
corr
# Out:
# array([[ 1.        ,  0.03259505, -0.07648546, -0.00486006, -0.03407156,
#         -0.01515608,  0.01496614, -0.02120862],
#        [ 0.03259505,  1.        ,  0.36024768, -0.17131821,  0.26555552,
#         -0.1022789 , -0.59180165, -0.76444054],
#        [-0.07648546,  0.36024768,  1.        ,  0.49800167,  0.8238437 ,
#          0.42912952, -0.85354226,  0.0702581 ],
#        [-0.00486006, -0.17131821,  0.49800167,  1.        ,  0.79163396,
#          0.93332522, -0.64023817,  0.7645671 ],
#        [-0.03407156,  0.26555552,  0.8238437 ,  0.79163396,  1.        ,
#          0.80812215, -0.89898837,  0.32646845],
#        [-0.01515608, -0.1022789 ,  0.42912952,  0.93332522,  0.80812215,
#          1.        , -0.62017634,  0.6719575 ],
#        [ 0.01496614, -0.59180165, -0.85354226, -0.64023817, -0.89898837,
#         -0.62017634,  1.        , -0.02348458],
#        [-0.02120862, -0.76444054,  0.0702581 ,  0.7645671 ,  0.32646845,
# ...

# %%
for i in range(corr.shape[0]):
  for j  in range(corr.shape[1]):
    if (i !=j) and (corr[i,j] == 1.):
      print(f'row = {i} column = {j} corrcoef = {corr[i,j]}')     # ไม่มี corrcoef = 1 แสดงว่าไม่มีแถวที่ซ้ำกัน

# %% [markdown]
# # plot กราฟ parallel coordinate

# %%
from matplotlib import pyplot as plt

# %%
pd.plotting.parallel_coordinates(data,'brand')

# %%
data_dropped = data.drop(['id'],axis=1)
data_dropped
# Out:
#     brand   mois   prot    fat   ash  sodium   carb   cal
# 0       A  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1       A  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2       A  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3       A  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4       A  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..    ...    ...    ...    ...   ...     ...    ...   ...
# 295     J  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296     J  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297     J  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298     J  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299     J  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 8 columns]

# %%
data_dropped1 = data.drop(['brand','id'],axis=1)   # ลบ column ที่ไม่ใช่ตัวเลขที่เป็นข้อมูล แต่เป็นชื่อกับรหัสออก
data_dropped1
# Out:
#       mois   prot    fat   ash  sodium   carb   cal
# 0    27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1    28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2    28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3    30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4    30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..     ...    ...    ...   ...     ...    ...   ...
# 295  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 7 columns]

# %%
pd.plotting.parallel_coordinates(data_dropped,'brand')

# %% [markdown]
# # ลดจำนวน Dimension ของข้อมูล โดยการทำ PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
new_pca = pca.fit_transform(data_dropped1.to_numpy())

# %%
new_pca.shape # ดูขนาดของ new_pca
# Out:
# (300, 2)

# %%
new_pca
# Out:
# array([[-2.49517479e+01,  2.68116678e+01],
#        [-2.46119758e+01,  2.56595634e+01],
#        [-2.49384190e+01,  2.69305710e+01],
#        [-2.43255609e+01,  2.35235671e+01],
#        [-2.38660483e+01,  2.26528128e+01],
#        [-2.42716473e+01,  2.25496261e+01],
#        [-2.38806695e+01,  2.18852969e+01],
#        [-2.23894923e+01,  2.39358506e+01],
#        [-2.45074215e+01,  2.66033180e+01],
#        [-2.50928469e+01,  2.71508163e+01],
#        [-2.48185674e+01,  2.76159021e+01],
#        [-2.39395254e+01,  2.75274080e+01],
#        [-2.44496724e+01,  2.62221990e+01],
#        [-2.28480039e+01,  2.27702098e+01],
#        [-2.42812192e+01,  2.25656557e+01],
#        [-2.38786302e+01,  2.39995991e+01],
#        [-2.32390338e+01,  1.96576785e+01],
#        [-2.36081213e+01,  1.88694931e+01],
#        [-2.34833228e+01,  2.08403006e+01],
#        [-2.30861647e+01,  2.25687679e+01],
#        [-2.44317537e+01,  2.88343106e+01],
#        [-2.39812139e+01,  2.72251577e+01],
# ...

# %% [markdown]
# # ดูว่ามี Brand อะไรบ้าง

# %% [markdown]
# ค่าที่เป็นไปได้ทั้งหมด

# %%
Br = set(data['brand'])
Br
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'}

# %% [markdown]
# # สร้าง Dictionary เพื่อแทนค่าที่เป็น text ให้เป็นตัวเลข เพื่อจะได้ plot สีได้

# %% [markdown]
# ## สร้าง ​color list แบบง่าย (เมื่อรันใหม่เลขลำดับอาจจะเปลี่ยนแปลง)

# %%
color_list = {}
num = 0
for each_br in Br:
    if each_br not in color_list:
        color_list[each_br] = num
        num += 1

# %%
 color_list
# Out:
# {'A': 2,
#  'B': 3,
#  'C': 0,
#  'D': 7,
#  'E': 5,
#  'F': 9,
#  'G': 8,
#  'H': 1,
#  'I': 4,
#  'J': 6}

# %% [markdown]
# ## สร้าง color list แบบข้างล่างนี้ ​ลำดับจะไม่มีการเปลี่ยนแปลง

# %%
Br_l = list(Br)     ### แปลงเป็น list
Br_l.sort()          ### เรียงค่า สมาชิกจากน้อยไปมาก
color_list2 = {}
num = 0
for each_br in Br_l:
    if each_br not in color_list2:
        color_list2[each_br] = num
        num += 1

# %%
color_list2
# Out:
# {'A': 0,
#  'B': 1,
#  'C': 2,
#  'D': 3,
#  'E': 4,
#  'F': 5,
#  'G': 6,
#  'H': 7,
#  'I': 8,
#  'J': 9}

# %% [markdown]
# ## แทนค่า text ใน Dictionary ด้วยตัวเลขที่เรากำหนด

# %%
data_dropped2 = data_dropped.replace(color_list2)

# %%
data_dropped2
# Out:
#      brand   mois   prot    fat   ash  sodium   carb   cal
# 0        0  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1        0  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2        0  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3        0  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4        0  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..     ...    ...    ...    ...   ...     ...    ...   ...
# 295      9  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296      9  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297      9  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298      9  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299      9  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 8 columns]

# %% [markdown]
# ### Plot กราฟ Scatter

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['brand'])

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['brand'],alpha=0.8)

# %% [markdown]
# ### เปรียบเทียบค่าของ fat และ cal

# %%
FC = data_dropped2[(data_dropped2['brand']==8) | (data_dropped2['brand']==9)]  ## ใช้  | และ  &  แทน  or  และ  and  ใน pandas
FC
# Out:
#      brand   mois   prot    fat   ash  sodium   carb   cal
# 239      8  54.64  10.36  12.89  2.21    0.53  19.90  2.37
# 240      8  54.52   9.85  13.55  2.04    0.47  20.05  2.42
# 241      8  53.84  10.22  13.05  2.07    0.48  20.82  2.42
# 242      8  54.32  10.66  14.04  2.03    0.46  18.95  2.45
# 243      8  52.90  10.19  14.35  2.02    0.49  20.54  2.52
# ..     ...    ...    ...    ...   ...     ...    ...   ...
# 295      9  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296      9  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297      9  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298      9  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299      9  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [61 rows x 8 columns]

# %%
pca = PCA(n_components=2)
new_pca2 = pca.fit_transform(sc.iloc[:,1:].to_numpy())

# %%
plt.scatter(new_pca2[:,0],new_pca2[:,1],c = sc['brand'],alpha=0.5)    # การกระจายข้อมูลของ fat กับ cal มีความแตกต่างกัน

# %%
fat_pca = pca.transform(fc[fc['brand']==8].iloc[:,1:].to_numpy())
cal_pca = pca.transform(fc[fc['brand']==9].iloc[:,1:].to_numpy())

# %%
plt.plot(fat_pca[:,0],fat_pca[:,1],'*c',alpha=0.5,label='fat')
plt.plot(cal_pca[:,0],cal_pca[:,1],'or',alpha=0.5,label='cal')
plt.legend()

# %% [markdown]
# ### 2 Principle components เป็นตัวแทนของข้อมูลได้ดีแค่ไหน

# %%
pca.explained_variance_ratio_         # plot 2 dimensions สามารถอธิบายข้อมูลได้ ประมาณ98% ถือว่าดี
# Out:
# array([0.99012446, 0.00915568])

# %% [markdown]
# ###  การใส่ชื่อกราฟ และ แกน

# %%
plt.plot(fat_pca[:,0],fat_pca[:,1],'or',alpha=0.5,label='fat')
plt.plot(cal_pca[:,0],cal_pca[:,1],'*c',alpha=0.5,label='cal')
plt.legend()
plt.title('comparison of nutritions between fat VS cal with PCA')
plt.xlabel('PC1 (99.01%)')
plt.ylabel('PC2 (0.91%)');                                                         # อธิบายได้เกิน 90% ไม่ทำต่อ

# %% [markdown]
# # การนำเข้าข้อมูล nndb_flat

# %%
import pandas as pd

# %%
data = pd.read_csv('nndb_flat.csv') #ตั้งชื่อตัวแปร
data                                             # แสดงข้อมูล
# Out:
#          ID                       FoodGroup  ... Selenium_USRDA Zinc_USRDA
# 0      1001          Dairy and Egg Products  ...       0.018182   0.008182
# 1      1002          Dairy and Egg Products  ...       0.018182   0.004545
# 2      1003          Dairy and Egg Products  ...       0.000000   0.000909
# 3      1004          Dairy and Egg Products  ...       0.263636   0.241818
# 4      1005          Dairy and Egg Products  ...       0.263636   0.236364
# ...     ...                             ...  ...            ...        ...
# 8613  83110  Finfish and Shellfish Products  ...       1.334545   0.100000
# 8614  90240  Finfish and Shellfish Products  ...       0.394545   0.140909
# 8615  90480                          Sweets  ...       0.012727   0.017273
# 8616  90560  Finfish and Shellfish Products  ...       0.498182   0.090909
# 8617  93600  Finfish and Shellfish Products  ...       0.305455   0.090909
#
# [8618 rows x 45 columns]

# %%
data = pd.read_csv('nndb_flat.csv') #กำหนดชื่อตัวแปร
data.head(10) #แสดงตัวอย่าง 10 ตัว
# Out:
#      ID               FoodGroup  ... Selenium_USRDA Zinc_USRDA
# 0  1001  Dairy and Egg Products  ...       0.018182   0.008182
# 1  1002  Dairy and Egg Products  ...       0.018182   0.004545
# 2  1003  Dairy and Egg Products  ...       0.000000   0.000909
# 3  1004  Dairy and Egg Products  ...       0.263636   0.241818
# 4  1005  Dairy and Egg Products  ...       0.263636   0.236364
# 5  1006  Dairy and Egg Products  ...       0.263636   0.216364
# 6  1007  Dairy and Egg Products  ...       0.263636   0.216364
# 7  1008  Dairy and Egg Products  ...       0.263636   0.267273
# 8  1009  Dairy and Egg Products  ...       0.514545   0.311818
# 9  1010  Dairy and Egg Products  ...       0.263636   0.253636
#
# [10 rows x 45 columns]

# %% [markdown]
# ## ตรวจสอบขนาดของข้อมูล

# %%
data.shape
# Out:
# (8618, 45)

# %% [markdown]
# ## plot scatter matrix เพื่อดูการกระจายของ data ในมุมมองต่างๆ

# %%
# pd.plotting.scatter_matrix(data)          #วิเคราะห์ต่อไม่ได้เพราะข้อมูลซ้อนทับกันเยอะเกิน

# %% [markdown]
# ### เนื่องจาก Data มี dimension มากเกินไป เราจะทดสอบดูว่า column ใด ให้ข้อมูลซ้ำกันกับ column อื่น แล้วลบมันออก

# %% [markdown]
# เลือกมาทำเฉพาะข้อมูลที่เป็นตัวเลข

# %%
data.iloc[:,7:]    # เอาทุกตัวยกเว้นแถวแรกถึงแถวที่ 6 โดยเริ่มจากแถวที่7
# Out:
#       Energy_kcal  Protein_g  ...  Selenium_USRDA  Zinc_USRDA
# 0           717.0       0.85  ...        0.018182    0.008182
# 1           717.0       0.85  ...        0.018182    0.004545
# 2           876.0       0.28  ...        0.000000    0.000909
# 3           353.0      21.40  ...        0.263636    0.241818
# 4           371.0      23.24  ...        0.263636    0.236364
# ...           ...        ...  ...             ...         ...
# 8613        305.0      18.50  ...        1.334545    0.100000
# 8614        111.0      20.54  ...        0.394545    0.140909
# 8615        269.0       0.00  ...        0.012727    0.017273
# 8616         90.0      16.10  ...        0.498182    0.090909
# 8617         89.0      19.80  ...        0.305455    0.090909
#
# [8618 rows x 38 columns]

# %%
newdata = data.iloc[:,7:]  # แสดงเฉพาะส่วนต้น
newdata.head()
# Out:
#    Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0        717.0       0.85  81.11  ...          0.034286        0.018182    0.008182
# 1        717.0       0.85  81.11  ...          0.032857        0.018182    0.004545
# 2        876.0       0.28  99.48  ...          0.004286        0.000000    0.000909
# 3        353.0      21.40  28.74  ...          0.552857        0.263636    0.241818
# 4        371.0      23.24  29.68  ...          0.644286        0.263636    0.236364
#
# [5 rows x 38 columns]

# %% [markdown]
# ### ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
corr = np.corrcoef(newdata.to_numpy().T)

# %%
corr.shape     # ดูขนาดของ corr
# Out:
# (38, 38)

# %%
corr
# Out:
# array([[1.        , 0.11030203, 0.80679472, ..., 0.19518065, 0.05667274,
#         0.11276635],
#        [0.11030203, 1.        , 0.05471538, ..., 0.44460761, 0.37836917,
#         0.41631538],
#        [0.80679472, 0.05471538, 1.        , ..., 0.06608644, 0.03755914,
#         0.02826352],
#        ...,
#        [0.19518065, 0.44460761, 0.06608644, ..., 1.        , 0.22368557,
#         0.26657694],
#        [0.05667274, 0.37836917, 0.03755914, ..., 0.22368557, 1.        ,
#         0.20529859],
#        [0.11276635, 0.41631538, 0.02826352, ..., 0.26657694, 0.20529859,
#         1.        ]])

# %%
for i in range(corr.shape[0]):  # วนลูปเพื่อดูค่า corr ว่าตัวใดมีค่าเท่ากับ1 โดยค่าต้องไม่มาจากเส้นทแยงมุม
    for j in range(corr.shape[1]):
        if (i !=j) and (corr[i,j] == 1.):
            print(f'column = {i} <=> column = {j} corrcoef = {corr[i,j]}')
# Out:
# column = 10 <=> column = 27 corrcoef = 1.0
# column = 12 <=> column = 29 corrcoef = 1.0
# column = 13 <=> column = 30 corrcoef = 1.0
# column = 14 <=> column = 31 corrcoef = 1.0
# column = 18 <=> column = 34 corrcoef = 1.0
# column = 20 <=> column = 35 corrcoef = 1.0
# column = 22 <=> column = 37 corrcoef = 1.0
# column = 27 <=> column = 10 corrcoef = 1.0
# column = 29 <=> column = 12 corrcoef = 1.0
# column = 30 <=> column = 13 corrcoef = 1.0
# column = 31 <=> column = 14 corrcoef = 1.0
# column = 34 <=> column = 18 corrcoef = 1.0
# column = 35 <=> column = 20 corrcoef = 1.0
# column = 37 <=> column = 22 corrcoef = 1.0

# %%
newdata.iloc[:5,10:30] #แสดงชื่อ colums ว่าสัมพันธ์กัน
# Out:
#    VitE_mg  Folate_mcg  Niacin_mg  ...  VitE_USRDA  Folate_USRDA  Niacin_USRDA
# 0     2.32         3.0      0.042  ...    0.154667        0.0075      0.002625
# 1     2.32         3.0      0.042  ...    0.154667        0.0075      0.002625
# 2     2.80         0.0      0.003  ...    0.186667        0.0000      0.000188
# 3     0.25        36.0      1.016  ...    0.016667        0.0900      0.063500
# 4     0.26        20.0      0.118  ...    0.017333        0.0500      0.007375
#
# [5 rows x 20 columns]

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### data ที่มี correlation เป็น 1

# %%
plt.plot(newdata.iloc[:,10],newdata.iloc[:,27],'r.')  # แสดงให้เห็นว่าแม้ข้อมูลจะไม่ใช่ตัวเดียวกัน แต่ค่า corr ก็เท่ากับ 1

# %%
plt.plot(newdata.iloc[:,10],newdata.iloc[:,10],'r.')

# %% [markdown]
# ### data ที่มี correlation เป็นค่าอื่นๆ

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,29],'r.')   # แสดงให้เห็นว่าข้อมูลจากคนละที่ ค่า corr เลยไม่เท่ากับ 1 และมีความแตกต่างกัน

# %% [markdown]
# ### ลบ column ซ้ำ

# %%
newdata.columns.str.contains('_USRDA')  #แสดงให้เห็นว่า คอลัมน์ไหนมี _USRDA บ้าง
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
newdata.columns[newdata.columns.str.contains('_USRDA')].values     # .values เพื่อแสดงเฉพาะค่าที่เป็น true
# Out:
# array(['VitA_USRDA', 'VitB6_USRDA', 'VitB12_USRDA', 'VitC_USRDA',
#        'VitE_USRDA', 'Folate_USRDA', 'Niacin_USRDA', 'Riboflavin_USRDA',
#        'Thiamin_USRDA', 'Calcium_USRDA', 'Copper_USRDA',
#        'Magnesium_USRDA', 'Phosphorus_USRDA', 'Selenium_USRDA',
#        'Zinc_USRDA'], dtype=object)

# %%
newdata.drop(newdata.columns[newdata.columns.str.contains('_USRDA')].values, axis=1)    # ถ้า axis = 1 จะลบคอลัมน์ทีมี _USRDA ทิ้ง
# Out:
#       Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_mg  Selenium_mcg  Zinc_mg
# 0           717.0       0.85  81.11  ...           24.0           1.0     0.09
# 1           717.0       0.85  81.11  ...           23.0           1.0     0.05
# 2           876.0       0.28  99.48  ...            3.0           0.0     0.01
# 3           353.0      21.40  28.74  ...          387.0          14.5     2.66
# 4           371.0      23.24  29.68  ...          451.0          14.5     2.60
# ...           ...        ...    ...  ...            ...           ...      ...
# 8613        305.0      18.50  25.10  ...          254.0          73.4     1.10
# 8614        111.0      20.54   0.84  ...          426.0          21.7     1.55
# 8615        269.0       0.00   0.00  ...            8.0           0.7     0.19
# 8616         90.0      16.10   1.40  ...          272.0          27.4     1.00
# 8617         89.0      19.80   0.50  ...          180.0          16.8     1.00
#
# ...

# %% [markdown]
# ### ลบ columns ที่มีค่า correlation เป็น 1 เมื่อเทียบกับ column อื่น

# %%
newdata_dropped = newdata.drop(['VitE_mg','Niacin_mg','Riboflavin_mg','Thiamin_mg','Magnesium_mg','Phosphorus_mg','Zinc_mg'], axis=1)
newdata_dropped     #ลบคอลัมน์ที่มี_mg ทิ้ง เนื่องจากซ้ำกัน และลบข้อมูลจากคอลัมน์ที่ไม่ต้องการทิ้งเพื่อที่จะได้ข้อมูลที่เป็นเฉพาะตัวเลข
# Out:
#       Energy_kcal  Protein_g  ...  Selenium_USRDA  Zinc_USRDA
# 0           717.0       0.85  ...        0.018182    0.008182
# 1           717.0       0.85  ...        0.018182    0.004545
# 2           876.0       0.28  ...        0.000000    0.000909
# 3           353.0      21.40  ...        0.263636    0.241818
# 4           371.0      23.24  ...        0.263636    0.236364
# ...           ...        ...  ...             ...         ...
# 8613        305.0      18.50  ...        1.334545    0.100000
# 8614        111.0      20.54  ...        0.394545    0.140909
# 8615        269.0       0.00  ...        0.012727    0.017273
# 8616         90.0      16.10  ...        0.498182    0.090909
# 8617         89.0      19.80  ...        0.305455    0.090909
#
# [8618 rows x 31 columns]

# %%
data_dropped = data.drop(['ID','ShortDescrip','Descrip','CommonName','MfgName','ScientificName','VitE_mg','Niacin_mg','Riboflavin_mg','Thiamin_mg','Magnesium_mg','Phosphorus_mg','Zinc_mg'], axis=1)
data_dropped
# Out:
#                            FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 0             Dairy and Egg Products        717.0  ...        0.018182    0.008182
# 1             Dairy and Egg Products        717.0  ...        0.018182    0.004545
# 2             Dairy and Egg Products        876.0  ...        0.000000    0.000909
# 3             Dairy and Egg Products        353.0  ...        0.263636    0.241818
# 4             Dairy and Egg Products        371.0  ...        0.263636    0.236364
# ...                              ...          ...  ...             ...         ...
# 8613  Finfish and Shellfish Products        305.0  ...        1.334545    0.100000
# 8614  Finfish and Shellfish Products        111.0  ...        0.394545    0.140909
# 8615                          Sweets        269.0  ...        0.012727    0.017273
# 8616  Finfish and Shellfish Products         90.0  ...        0.498182    0.090909
# ...

# %% [markdown]
# ### ทดลอง plot กราฟ parallel coordinate

# %%
pd.plotting.parallel_coordinates(data_dropped,'FoodGroup',cols=['Protein_g','Fat_g','Carb_g','Sugar_g',	'Fiber_g'])

# %% [markdown]
# ### ทำ PCA เพื่อลดจำนวน Dimension ของข้อมูล

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)    #plot dimensions 2 ตัวแรก

# %%
new_pca = pca.fit_transform(newdata_dropped.to_numpy())

# %%
new_pca.shape    # ดูขนาดของ new_pca
# Out:
# (8618, 2)

# %%
new_pca
# Out:
# array([[ 590.95286674,   85.56968946],
#        [ 590.95284476,   85.57159456],
#        [ 747.5994042 ,  117.79120834],
#        ...,
#        [ -95.72739188,  -53.51885094],
#        [ -66.70492177, -118.10632681],
#        [ -65.40356382,  -28.88067151]])

# %% [markdown]
# ### ดูว่ามี food group อะไรบ้าง

# %%
FG = set(data['FoodGroup'])
FG
# Out:
# {'American Indian/Alaska Native Foods',
#  'Baby Foods',
#  'Baked Products',
#  'Beef Products',
#  'Beverages',
#  'Breakfast Cereals',
#  'Cereal Grains and Pasta',
#  'Dairy and Egg Products',
#  'Fast Foods',
#  'Fats and Oils',
#  'Finfish and Shellfish Products',
#  'Fruits and Fruit Juices',
#  'Lamb, Veal, and Game Products',
#  'Legumes and Legume Products',
#  'Meals, Entrees, and Side Dishes',
#  'Nut and Seed Products',
#  'Pork Products',
#  'Poultry Products',
#  'Restaurant Foods',
#  'Sausages and Luncheon Meats',
#  'Snacks',
#  'Soups, Sauces, and Gravies',
#  'Spices and Herbs',
#  'Sweets',
#  'Vegetables and Vegetable Products'}

# %% [markdown]
# ### สร้าง Dictionary เพื่อแทนค่าที่เป็น text ให้เป็นตัวเลข เพื่อจะได้ plot สีได้

# %% [markdown]
# #### สร้าง ​color list แบบง่าย (เมื่อรันใหม่เลขลำดับอาจจะเปลี่ยนแปลง)

# %%
 color_list = {}
num = 0
for each_fg in FG:
     if each_fg not in color_list:
         color_list[each_fg] = num
         num += 1

# %%
color_list
# Out:
# {'American Indian/Alaska Native Foods': 5,
#  'Baby Foods': 10,
#  'Baked Products': 0,
#  'Beef Products': 16,
#  'Beverages': 3,
#  'Breakfast Cereals': 21,
#  'Cereal Grains and Pasta': 19,
#  'Dairy and Egg Products': 11,
#  'Fast Foods': 17,
#  'Fats and Oils': 23,
#  'Finfish and Shellfish Products': 20,
#  'Fruits and Fruit Juices': 4,
#  'Lamb, Veal, and Game Products': 6,
#  'Legumes and Legume Products': 18,
#  'Meals, Entrees, and Side Dishes': 22,
#  'Nut and Seed Products': 24,
#  'Pork Products': 13,
#  'Poultry Products': 14,
#  'Restaurant Foods': 7,
#  'Sausages and Luncheon Meats': 1,
#  'Snacks': 2,
#  'Soups, Sauces, and Gravies': 15,
#  'Spices and Herbs': 8,
#  'Sweets': 12,
#  'Vegetables and Vegetable Products': 9}

# %% [markdown]
# #### สร้าง color list แบบข้างล่างนี้ ​ลำดับจะไม่มีการเปลี่ยนแปลง

# %%
FG_l = list(FG)  ### แปลงเป็น list
FG_l.sort() ### เรียงค่่า สมาชิกจากน้อยไปมาก
color_list2 = {}
num = 0
for each_fg in FG_l:
    if each_fg not in color_list2:
        color_list2[each_fg] = num
        num += 1

# %%
color_list2
# Out:
# {'American Indian/Alaska Native Foods': 0,
#  'Baby Foods': 1,
#  'Baked Products': 2,
#  'Beef Products': 3,
#  'Beverages': 4,
#  'Breakfast Cereals': 5,
#  'Cereal Grains and Pasta': 6,
#  'Dairy and Egg Products': 7,
#  'Fast Foods': 8,
#  'Fats and Oils': 9,
#  'Finfish and Shellfish Products': 10,
#  'Fruits and Fruit Juices': 11,
#  'Lamb, Veal, and Game Products': 12,
#  'Legumes and Legume Products': 13,
#  'Meals, Entrees, and Side Dishes': 14,
#  'Nut and Seed Products': 15,
#  'Pork Products': 16,
#  'Poultry Products': 17,
#  'Restaurant Foods': 18,
#  'Sausages and Luncheon Meats': 19,
#  'Snacks': 20,
#  'Soups, Sauces, and Gravies': 21,
#  'Spices and Herbs': 22,
#  'Sweets': 23,
#  'Vegetables and Vegetable Products': 24}

# %% [markdown]
# ### แทนค่า text ใน Dictionary ด้วยตัวเลขที่เรากำหนด

# %%
data_dropped2 = data_dropped.replace(color_list2)

# %%
data_dropped2
# Out:
#       FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 0             7        717.0  ...        0.018182    0.008182
# 1             7        717.0  ...        0.018182    0.004545
# 2             7        876.0  ...        0.000000    0.000909
# 3             7        353.0  ...        0.263636    0.241818
# 4             7        371.0  ...        0.263636    0.236364
# ...         ...          ...  ...             ...         ...
# 8613         10        305.0  ...        1.334545    0.100000
# 8614         10        111.0  ...        0.394545    0.140909
# 8615         23        269.0  ...        0.012727    0.017273
# 8616         10         90.0  ...        0.498182    0.090909
# 8617         10         89.0  ...        0.305455    0.090909
#
# [8618 rows x 32 columns]

# %% [markdown]
# ### Plot กราฟ Scatter

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['FoodGroup'])   # แก้ไขกราฟ เนื่องจากข้อมูลซ้อนทับกัน

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['FoodGroup'],alpha=0.3)   # ใส่ alpha เพื่อให้สีข้อมูลจางลงเพื่อจะได้มองง่ายขึ้น

# %% [markdown]
# ### ทดลอง เปรียบเทียบค่าสารอาหาร Breakfast Cereals และ Fast Foods

# %%
bf = data_dropped2[(data_dropped2['FoodGroup']==5) | (data_dropped2['FoodGroup']==8)]  ## ใช้  | และ  &  แทน  or  และ  and  ใน pandas
bf
# Out:
#       FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 1816          5        260.0  ...        0.170909    1.127273
# 1817          5        389.0  ...        0.380000    0.454545
# 1818          5        375.0  ...        0.101818    0.490909
# 1819          5        257.0  ...        0.525455    0.454545
# 1820          5        398.0  ...        0.118182    1.469091
# ...         ...          ...  ...             ...         ...
# 8513          5        385.0  ...        0.314545    0.248182
# 8556          5        339.0  ...        0.149091    0.284545
# 8573          5        354.0  ...        0.052727    0.143636
# 8574          5        380.0  ...        0.481818    0.200000
# 8592          5        401.0  ...        0.132727    0.457273
#
# [734 rows x 32 columns]

# %%
pca = PCA(n_components=2)
new_pca2 = pca.fit_transform(bf.iloc[:,1:].to_numpy())

# %%
plt.scatter(new_pca2[:,0],new_pca2[:,1],c = bf ['FoodGroup'],alpha=0.5)

# %% [markdown]
# จากการกระจายของข้อมูล คาดว่าสีเหลืองเป็น fast foods เนื่องจากสารอาหารไม่ค่อยหลากหลาย ข้อมูลจึงไม่กระจาย ส่วนสีม่วงน่าจะเป็น breakfast cereals เนื่องจากข้อมูลค่อนข้างกระจายเพราะสารอาหารค่อนข้างหลากหลาย

# %%
break_pca = pca.transform(bf[bf['FoodGroup']==5].iloc[:,1:].to_numpy())
fast_pca = pca.transform(bf[bf['FoodGroup']==8].iloc[:,1:].to_numpy())

# %%
plt.plot(break_pca[:,0],break_pca[:,1],'oc',alpha=0.5,label='break')
plt.plot(fast_pca[:,0],fast_pca[:,1],'*r',alpha=0.5,label='fast')
plt.legend()

# %% [markdown]
# ### 2 Principle components เป็นตัวแทนของข้อมูลได้ดีแค่ไหน

# %%
pca.explained_variance_ratio_      # อธิบายข้อมูลที่นำมาเปรียบเทียบ โดยแสดงเป็นเปอร์เซ็นต์
# Out:
# array([0.73983867, 0.13806995])

# %% [markdown]
# ### การใส่ชื่อกราฟ และ แกน

# %%
plt.plot(break_pca[:,0],break_pca[:,1],'oc',alpha=0.5,label='break')
plt.plot(fast_pca[:,0],fast_pca[:,1],'*r',alpha=0.5,label='fast')
plt.legend()
plt.title('comparison of nutritions between fast food VS breakfast cereals with PCA')
plt.xlabel('PC1 (73.98%)')
plt.ylabel('PC2 (13.80%)');

# %% [markdown]
# ### ลองทำ PCA ใหม่ เพราะ PC1 + PC2 ยังอธิบายข้อมูลได้ไม่ถึง 90%

# %%
pca = PCA()
new_pca3 = pca.fit_transform(bf.iloc[:,1:].to_numpy())

# %%
pca.explained_variance_ratio_
# Out:
# array([7.39838668e-01, 1.38069946e-01, 9.72913889e-02, 2.16595288e-02,
#        1.33260824e-03, 8.97001763e-04, 4.61869111e-04, 2.22432865e-04,
#        1.06893183e-04, 6.06402138e-05, 4.04845954e-05, 9.51251731e-06,
#        5.42254550e-06, 1.71325591e-06, 8.88537635e-07, 4.15811968e-07,
#        2.66682465e-07, 1.37161537e-07, 6.95815215e-08, 4.10687512e-08,
#        3.26270350e-08, 3.07645476e-08, 6.97603190e-09, 5.99954749e-33,
#        5.99954749e-33, 5.99954749e-33, 5.99954749e-33, 5.99954749e-33,
#        5.99954749e-33, 5.99954749e-33, 5.99954749e-33])

# %%
sum(pca.explained_variance_ratio_[:3])
# Out:
# 0.9752000036943904

# %%
pca2 = PCA(n_components=3)
new_pca3 = pca2.fit_transform(bf.iloc[:,1:].to_numpy())

# %%
new_pca3
# Out:
# array([[1967.40602552, -280.47873885,  108.65932396],
#        [1010.06446773,  268.72286902, -210.82730774],
#        [ 445.11099842,  248.60886184, -179.5835441 ],
#        ...,
#        [-215.08401051,  -67.7876913 ,  -92.05917045],
#        [  27.84905144, -142.21364008,  -32.06636452],
#        [1031.10656404,  328.42526002, -230.66751336]])

# %%
break_pca3 = pca2.transform(bf[bf['FoodGroup']==5].iloc[:,1:].to_numpy())
fast_pca3 = pca2.transform(bf[bf['FoodGroup']==8].iloc[:,1:].to_numpy())

# %%
break_pca3
# Out:
# array([[1967.40602552, -280.47873885,  108.65932396],
#        [1010.06446773,  268.72286902, -210.82730774],
#        [ 445.11099842,  248.60886184, -179.5835441 ],
#        ...,
#        [-215.08401051,  -67.7876913 ,  -92.05917045],
#        [  27.84905144, -142.21364008,  -32.06636452],
#        [1031.10656404,  328.42526002, -230.66751336]])

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(break_pca3[:,0],break_pca3[:,1],break_pca3[:,2],c='g')
ax.scatter3D(fast_pca3[:,0],fast_pca3[:,1],fast_pca3[:,2],c='r')
ax.set_title('Comparison of nutritions between fast food VS breakfast cereals with PCA')
ax.set_xlabel('PC1 (73.98%)')
ax.set_ylabel('PC2 (13.80%)')
ax.set_zlabel('PC3 (9.73%)');

# %% [markdown]
# ### Eigen Vectors

# %% [markdown]
# 3.11513052e-04 = $3.11 x 10^{-4}$

# %%
pca2.components_
# Out:
# array([[ 7.55389412e-02, -2.11741973e-03, -4.06637623e-03,
#          3.24196588e-02,  1.35562159e-02,  2.80534832e-03,
#          3.30833112e-01,  1.57945571e-03,  3.78918470e-03,
#          1.89300011e-02,  9.35475001e-01,  8.87328867e-02,
#          8.06689455e-05,  1.42398526e-02,  6.39469426e-04,
#          1.77821160e-03,  3.67592347e-04,  9.29091592e-04,
#          1.57882696e-03,  2.10333346e-04,  2.11127950e-04,
#          2.33868750e-03,  7.08334341e-04,  7.64489211e-04,
#          7.43478605e-04,  7.39440723e-05,  8.96321616e-08,
#          5.17904080e-05,  5.15734355e-05,  3.23311199e-05,
#          6.12612801e-04],
#        [ 6.14334177e-02, -2.41948048e-03, -2.26894272e-03,
#          2.09211160e-02,  9.02760448e-03, -1.29924933e-03,
#          9.31050933e-01,  7.40723964e-04,  2.69224548e-03,
#          1.80632412e-02, -3.44819518e-01,  9.77579309e-02,
#          9.79875770e-05,  3.97594949e-03,  6.78065530e-05,
# ...

# %%
import numpy as np

# %%
np.argmax(pca2.components_[0,:])
# Out:
# 10
